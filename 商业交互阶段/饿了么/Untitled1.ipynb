# %%
with open('北京经纬度.txt','r')as f:
    text = f.readlines()
text
# Out:
# ['115.9795,39.6895,北京市,北京市,131,房山区,110111\n',
#  '115.9795,39.7165,北京市,北京市,131,房山区,110111\n',
#  '115.9795,39.7435,北京市,北京市,131,房山区,110111\n',
#  '115.9795,39.7705,北京市,北京市,131,房山区,110111\n',
#  '115.9795,39.7975,北京市,北京市,131,房山区,110111\n',
#  '115.9795,39.8245,北京市,北京市,131,房山区,110111\n',
#  '115.9795,39.8515,北京市,北京市,131,房山区,110111\n',
#  '116.0065,39.6625,北京市,北京市,131,房山区,110111\n',
#  '116.0065,39.6895,北京市,北京市,131,房山区,110111\n',
#  '116.0065,39.7165,北京市,北京市,131,房山区,110111\n',
#  '116.0065,39.7435,北京市,北京市,131,房山区,110111\n',
#  '116.0065,39.7705,北京市,北京市,131,房山区,110111\n',
#  '116.0065,39.7975,北京市,北京市,131,房山区,110111\n',
#  '116.0065,39.8245,北京市,北京市,131,房山区,110111\n',
#  '116.0065,39.8515,北京市,北京市,131,门头沟区,110109\n',
#  '116.0065,39.8785,北京市,北京市,131,门头沟区,110109\n',
#  '116.0065,39.9055,北京市,北京市,131,门头沟区,110109\n',
#  '116.0065,39.9325,北京市,北京市,131,门头沟区,110109\n',
#  '116.0335,39.6085,北京市,北京市,131,房山区,110111\n',
#  '116.0335,39.6355,北京市,北京市,131,房山区,110111\n',
# ...

# %%
lat_long = []
for i in range(len(text)):
    lat_long.append(text[i].split(',')[:2])

# %%
def get_lat_long():
    with open('北京经纬度.txt','r')as f:
        text = f.readlines()
    lat_long = []
    for i in range(len(text)):
        lat_long.append(text[i].split(',')[:2])
    return lat_long
